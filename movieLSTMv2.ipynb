# %%
import os
import random
from tqdm import tqdm

def get_random_text(text, chunk_size=200):
    start_index = random.randint(0, len(text) - chunk_size)
    return text[start_index:start_index + chunk_size]

def sample_scripts(input_folder, output_file):
    with open(output_file, 'w', encoding='utf-8') as output:
        for filename in tqdm(os.listdir(input_folder)):
            if filename.endswith(".txt"):
                file_path = os.path.join(input_folder, filename)
                
                with open(file_path, 'r', encoding='utf-8') as file:
                    file_content = file.read()
                    #random_text = get_random_text(file_content)
                    #output.write(random_text + '\n')
                    output.write(file_content + '\n')

input_folder = "movie_scripts"
output_file = "samplerv2.txt" 

sample_scripts(input_folder, output_file)
# Out:
# 100%|██████████| 1092/1092 [00:57<00:00, 19.09it/s]

# %%
from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding

def load_doc(filename):
	file = open(filename, 'r')
	text = file.read()
	file.close()
	return text

doc = load_doc('bladeTrilogy.txt')
lines = doc.split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)
sequences = pad_sequences(sequences)
unique_words_count = len(tokenizer.word_index) + 1

sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=unique_words_count)
seq_length = X.shape[1]

model = Sequential()
model.add(Embedding(len(tokenizer.word_index) + 1, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(unique_words_count, activation='softmax'))
print(model.summary())

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X, y, batch_size=128, epochs=250)

model.save('model2.h5')
dump(tokenizer, open('tokenizer2.pkl', 'wb'))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 44, 50)            347350
#
#  lstm_4 (LSTM)               (None, 44, 100)           60400
#
#  lstm_5 (LSTM)               (None, 100)               80400
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 6947)              701647
#
# =================================================================
# Total params: 1199897 (4.58 MB)
# Trainable params: 1199897 (4.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/250
# 11/11 [==============================] - 25s 209ms/step - loss: 8.8374 - accuracy: 0.0652
# Epoch 2/250
# 11/11 [==============================] - 2s 219ms/step - loss: 8.3050 - accuracy: 0.0697
# Epoch 3/250
# 11/11 [==============================] - 2s 219ms/step - loss: 6.7715 - accuracy: 0.0697
# Epoch 4/250
# 11/11 [==============================] - 2s 225ms/step - loss: 6.3925 - accuracy: 0.0697
# Epoch 5/250
# 11/11 [==============================] - 4s 329ms/step - loss: 6.3061 - accuracy: 0.0697
# Epoch 6/250
# 11/11 [==============================] - 2s 208ms/step - loss: 6.2786 - accuracy: 0.0697
# Epoch 7/250
# 11/11 [==============================] - 2s 206ms/step - loss: 6.2668 - accuracy: 0.0697
# Epoch 8/250
# 11/11 [==============================] - 2s 214ms/step - loss: 6.2606 - accuracy: 0.0697
# Epoch 9/250
# 11/11 [==============================] - 2s 215ms/step - loss: 6.2660 - accuracy: 0.0697
# Epoch 10/250
# 11/11 [==============================] - 2s 221ms/step - loss: 6.2603 - accuracy: 0.0697
# Epoch 11/250
# 11/11 [==============================] - 3s 237ms/step - loss: 6.2540 - accuracy: 0.0697
# Epoch 12/250
# 11/11 [==============================] - 3s 224ms/step - loss: 6.2536 - accuracy: 0.0697
# Epoch 13/250
# 11/11 [==============================] - 3s 228ms/step - loss: 6.2499 - accuracy: 0.0697
# Epoch 14/250
# 11/11 [==============================] - 2s 209ms/step - loss: 6.2503 - accuracy: 0.0697
# Epoch 15/250
# 11/11 [==============================] - 2s 199ms/step - loss: 6.2507 - accuracy: 0.0697
# Epoch 16/250
# 11/11 [==============================] - 2s 213ms/step - loss: 6.2448 - accuracy: 0.0697
# Epoch 17/250
# 11/11 [==============================] - 2s 219ms/step - loss: 6.2474 - accuracy: 0.0697
# Epoch 18/250
# 11/11 [==============================] - 4s 365ms/step - loss: 6.2429 - accuracy: 0.0697
# Epoch 19/250
# 11/11 [==============================] - 2s 209ms/step - loss: 6.2432 - accuracy: 0.0697
# Epoch 20/250
# 11/11 [==============================] - 2s 206ms/step - loss: 6.2448 - accuracy: 0.0697
# Epoch 21/250
# 11/11 [==============================] - 2s 208ms/step - loss: 6.2410 - accuracy: 0.0697
# Epoch 22/250
# 11/11 [==============================] - 2s 207ms/step - loss: 6.2403 - accuracy: 0.0697
# Epoch 23/250
# 11/11 [==============================] - 2s 211ms/step - loss: 6.2368 - accuracy: 0.0697
# Epoch 24/250
# 11/11 [==============================] - 4s 360ms/step - loss: 6.2349 - accuracy: 0.0697
# Epoch 25/250
# 11/11 [==============================] - 3s 216ms/step - loss: 6.2369 - accuracy: 0.0697
# Epoch 26/250
# 11/11 [==============================] - 3s 236ms/step - loss: 6.2333 - accuracy: 0.0697
# Epoch 27/250
# 11/11 [==============================] - 2s 210ms/step - loss: 6.2317 - accuracy: 0.0697
# Epoch 28/250
# 11/11 [==============================] - 2s 211ms/step - loss: 6.2297 - accuracy: 0.0697
# Epoch 29/250
# 11/11 [==============================] - 3s 244ms/step - loss: 6.2231 - accuracy: 0.0697
# Epoch 30/250
# 11/11 [==============================] - 2s 226ms/step - loss: 6.2149 - accuracy: 0.0697
# Epoch 31/250
# 11/11 [==============================] - 3s 304ms/step - loss: 6.1872 - accuracy: 0.0697
# Epoch 32/250
# 11/11 [==============================] - 2s 211ms/step - loss: 6.1316 - accuracy: 0.0697
# Epoch 33/250
# 11/11 [==============================] - 2s 209ms/step - loss: 6.0602 - accuracy: 0.0697
# Epoch 34/250
# 11/11 [==============================] - 2s 205ms/step - loss: 6.0015 - accuracy: 0.0697
# Epoch 35/250
# 11/11 [==============================] - 2s 209ms/step - loss: 5.9541 - accuracy: 0.0705
# Epoch 36/250
# 11/11 [==============================] - 2s 224ms/step - loss: 5.9089 - accuracy: 0.0705
# Epoch 37/250
# 11/11 [==============================] - 4s 365ms/step - loss: 5.8689 - accuracy: 0.0705
# Epoch 38/250
# 11/11 [==============================] - 3s 223ms/step - loss: 5.8234 - accuracy: 0.0705
# Epoch 39/250
# 11/11 [==============================] - 2s 217ms/step - loss: 5.7767 - accuracy: 0.0705
# Epoch 40/250
# 11/11 [==============================] - 2s 211ms/step - loss: 5.7171 - accuracy: 0.0705
# Epoch 41/250
# 11/11 [==============================] - 2s 214ms/step - loss: 5.6580 - accuracy: 0.0705
# Epoch 42/250
# 11/11 [==============================] - 3s 232ms/step - loss: 5.6025 - accuracy: 0.0712
# Epoch 43/250
# 11/11 [==============================] - 4s 363ms/step - loss: 5.5464 - accuracy: 0.0712
# Epoch 44/250
# 11/11 [==============================] - 3s 237ms/step - loss: 5.4962 - accuracy: 0.0705
# Epoch 45/250
# 11/11 [==============================] - 2s 224ms/step - loss: 5.4383 - accuracy: 0.0720
# Epoch 46/250
# 11/11 [==============================] - 2s 219ms/step - loss: 5.3998 - accuracy: 0.0720
# Epoch 47/250
# 11/11 [==============================] - 2s 210ms/step - loss: 5.3539 - accuracy: 0.0765
# Epoch 48/250
# 11/11 [==============================] - 3s 285ms/step - loss: 5.3076 - accuracy: 0.0758
# Epoch 49/250
# 11/11 [==============================] - 3s 263ms/step - loss: 5.2585 - accuracy: 0.0773
# Epoch 50/250
# 11/11 [==============================] - 3s 237ms/step - loss: 5.2050 - accuracy: 0.0780
# Epoch 51/250
# 11/11 [==============================] - 3s 250ms/step - loss: 5.1304 - accuracy: 0.0742
# Epoch 52/250
# 11/11 [==============================] - 2s 210ms/step - loss: 5.0455 - accuracy: 0.0909
# Epoch 53/250
# 11/11 [==============================] - 2s 220ms/step - loss: 4.9608 - accuracy: 0.0924
# Epoch 54/250
# 11/11 [==============================] - 3s 256ms/step - loss: 4.8544 - accuracy: 0.0917
# Epoch 55/250
# 11/11 [==============================] - 3s 229ms/step - loss: 4.7497 - accuracy: 0.0977
# Epoch 56/250
# 11/11 [==============================] - 2s 206ms/step - loss: 4.6413 - accuracy: 0.1053
# Epoch 57/250
# 11/11 [==============================] - 3s 243ms/step - loss: 4.5028 - accuracy: 0.1038
# Epoch 58/250
# 11/11 [==============================] - 3s 243ms/step - loss: 4.3746 - accuracy: 0.1114
# Epoch 59/250
# 11/11 [==============================] - 3s 236ms/step - loss: 4.2653 - accuracy: 0.1083
# Epoch 60/250
# 11/11 [==============================] - 3s 241ms/step - loss: 4.1543 - accuracy: 0.1136
# Epoch 61/250
# 11/11 [==============================] - 2s 184ms/step - loss: 4.0193 - accuracy: 0.1273
# Epoch 62/250
# 11/11 [==============================] - 2s 190ms/step - loss: 3.9246 - accuracy: 0.1280
# Epoch 63/250
# 11/11 [==============================] - 2s 211ms/step - loss: 3.8249 - accuracy: 0.1364
# Epoch 64/250
# 11/11 [==============================] - 2s 202ms/step - loss: 3.7164 - accuracy: 0.1371
# Epoch 65/250
# 11/11 [==============================] - 2s 209ms/step - loss: 3.6151 - accuracy: 0.1576
# Epoch 66/250
# 11/11 [==============================] - 2s 218ms/step - loss: 3.5117 - accuracy: 0.1697
# Epoch 67/250
# 11/11 [==============================] - 3s 324ms/step - loss: 3.4126 - accuracy: 0.1765
# Epoch 68/250
# 11/11 [==============================] - 3s 287ms/step - loss: 3.3080 - accuracy: 0.1939
# Epoch 69/250
# 11/11 [==============================] - 3s 241ms/step - loss: 3.2360 - accuracy: 0.1932
# Epoch 70/250
# 11/11 [==============================] - 3s 231ms/step - loss: 3.1622 - accuracy: 0.2061
# Epoch 71/250
# 11/11 [==============================] - 3s 231ms/step - loss: 3.1104 - accuracy: 0.2159
# Epoch 72/250
# 11/11 [==============================] - 2s 210ms/step - loss: 3.0365 - accuracy: 0.2227
# Epoch 73/250
# 11/11 [==============================] - 2s 212ms/step - loss: 2.9338 - accuracy: 0.2826
# Epoch 74/250
# 11/11 [==============================] - 3s 242ms/step - loss: 2.8475 - accuracy: 0.2712
# Epoch 75/250
# 11/11 [==============================] - 2s 214ms/step - loss: 2.7528 - accuracy: 0.2939
# Epoch 76/250
# 11/11 [==============================] - 2s 204ms/step - loss: 2.6702 - accuracy: 0.3182
# Epoch 77/250
# 11/11 [==============================] - 2s 203ms/step - loss: 2.5866 - accuracy: 0.3553
# Epoch 78/250
# 11/11 [==============================] - 2s 203ms/step - loss: 2.5193 - accuracy: 0.3773
# Epoch 79/250
# 11/11 [==============================] - 3s 235ms/step - loss: 2.4659 - accuracy: 0.3727
# Epoch 80/250
# 11/11 [==============================] - 3s 307ms/step - loss: 2.4041 - accuracy: 0.3970
# Epoch 81/250
# 11/11 [==============================] - 2s 215ms/step - loss: 2.3368 - accuracy: 0.4212
# Epoch 82/250
# 11/11 [==============================] - 2s 206ms/step - loss: 2.3148 - accuracy: 0.4068
# Epoch 83/250
# 11/11 [==============================] - 2s 210ms/step - loss: 2.2829 - accuracy: 0.4288
# Epoch 84/250
# 11/11 [==============================] - 2s 212ms/step - loss: 2.2272 - accuracy: 0.4311
# Epoch 85/250
# 11/11 [==============================] - 2s 225ms/step - loss: 2.1545 - accuracy: 0.4712
# Epoch 86/250
# 11/11 [==============================] - 3s 284ms/step - loss: 2.1138 - accuracy: 0.4758
# Epoch 87/250
# 11/11 [==============================] - 2s 213ms/step - loss: 2.0662 - accuracy: 0.4894
# Epoch 88/250
# 11/11 [==============================] - 2s 210ms/step - loss: 1.9922 - accuracy: 0.5326
# Epoch 89/250
# 11/11 [==============================] - 2s 202ms/step - loss: 1.9329 - accuracy: 0.5538
# Epoch 90/250
# 11/11 [==============================] - 2s 207ms/step - loss: 1.8744 - accuracy: 0.5742
# Epoch 91/250
# 11/11 [==============================] - 3s 232ms/step - loss: 1.8166 - accuracy: 0.6045
# Epoch 92/250
# 11/11 [==============================] - 3s 303ms/step - loss: 1.7760 - accuracy: 0.6053
# Epoch 93/250
# 11/11 [==============================] - 3s 263ms/step - loss: 1.7302 - accuracy: 0.6106
# Epoch 94/250
# 11/11 [==============================] - 3s 253ms/step - loss: 1.7433 - accuracy: 0.5939
# Epoch 95/250
# 11/11 [==============================] - 3s 237ms/step - loss: 1.7151 - accuracy: 0.6197
# Epoch 96/250
# 11/11 [==============================] - 3s 230ms/step - loss: 1.6778 - accuracy: 0.6174
# Epoch 97/250
# 11/11 [==============================] - 3s 230ms/step - loss: 1.6272 - accuracy: 0.6280
# Epoch 98/250
# 11/11 [==============================] - 2s 218ms/step - loss: 1.5810 - accuracy: 0.6500
# Epoch 99/250
# 11/11 [==============================] - 2s 220ms/step - loss: 1.5425 - accuracy: 0.6614
# Epoch 100/250
# 11/11 [==============================] - 3s 242ms/step - loss: 1.4989 - accuracy: 0.6864
# Epoch 101/250
# 11/11 [==============================] - 3s 275ms/step - loss: 1.4533 - accuracy: 0.6992
# Epoch 102/250
# 11/11 [==============================] - 3s 281ms/step - loss: 1.4165 - accuracy: 0.7083
# Epoch 103/250
# 11/11 [==============================] - 3s 279ms/step - loss: 1.3729 - accuracy: 0.7114
# Epoch 104/250
# 11/11 [==============================] - 3s 240ms/step - loss: 1.3346 - accuracy: 0.7409
# Epoch 105/250
# 11/11 [==============================] - 3s 264ms/step - loss: 1.2992 - accuracy: 0.7447
# Epoch 106/250
# 11/11 [==============================] - 3s 275ms/step - loss: 1.2741 - accuracy: 0.7424
# Epoch 107/250
# 11/11 [==============================] - 3s 302ms/step - loss: 1.2480 - accuracy: 0.7667
# Epoch 108/250
# 11/11 [==============================] - 3s 274ms/step - loss: 1.2114 - accuracy: 0.7576
# Epoch 109/250
# 11/11 [==============================] - 3s 253ms/step - loss: 1.2003 - accuracy: 0.7667
# Epoch 110/250
# 11/11 [==============================] - 2s 220ms/step - loss: 1.1496 - accuracy: 0.7841
# Epoch 111/250
# 11/11 [==============================] - 2s 220ms/step - loss: 1.1194 - accuracy: 0.7917
# Epoch 112/250
# 11/11 [==============================] - 2s 218ms/step - loss: 1.1027 - accuracy: 0.8030
# Epoch 113/250
# 11/11 [==============================] - 2s 209ms/step - loss: 1.0760 - accuracy: 0.8106
# Epoch 114/250
# 11/11 [==============================] - 2s 217ms/step - loss: 1.0407 - accuracy: 0.8212
# Epoch 115/250
# 11/11 [==============================] - 3s 226ms/step - loss: 1.0255 - accuracy: 0.8068
# Epoch 116/250
# 11/11 [==============================] - 4s 323ms/step - loss: 1.0092 - accuracy: 0.8174
# Epoch 117/250
# 11/11 [==============================] - 2s 226ms/step - loss: 0.9926 - accuracy: 0.8220
# Epoch 118/250
# 11/11 [==============================] - 2s 224ms/step - loss: 0.9663 - accuracy: 0.8326
# Epoch 119/250
# 11/11 [==============================] - 2s 224ms/step - loss: 0.9609 - accuracy: 0.8273
# Epoch 120/250
# 11/11 [==============================] - 2s 221ms/step - loss: 0.9336 - accuracy: 0.8364
# Epoch 121/250
# 11/11 [==============================] - 2s 220ms/step - loss: 0.9212 - accuracy: 0.8311
# Epoch 122/250
# 11/11 [==============================] - 3s 254ms/step - loss: 0.9033 - accuracy: 0.8394
# Epoch 123/250
# 11/11 [==============================] - 3s 247ms/step - loss: 0.8941 - accuracy: 0.8333
# Epoch 124/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.8737 - accuracy: 0.8500
# Epoch 125/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.8600 - accuracy: 0.8515
# Epoch 126/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8503 - accuracy: 0.8485
# Epoch 127/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.8323 - accuracy: 0.8402
# Epoch 128/250
# 11/11 [==============================] - 3s 231ms/step - loss: 0.8120 - accuracy: 0.8515
# Epoch 129/250
# 11/11 [==============================] - 4s 336ms/step - loss: 0.7933 - accuracy: 0.8545
# Epoch 130/250
# 11/11 [==============================] - 4s 343ms/step - loss: 0.7827 - accuracy: 0.8583
# Epoch 131/250
# 11/11 [==============================] - 2s 202ms/step - loss: 0.7692 - accuracy: 0.8667
# Epoch 132/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7507 - accuracy: 0.8750
# Epoch 133/250
# 11/11 [==============================] - 2s 210ms/step - loss: 0.7406 - accuracy: 0.8667
# Epoch 134/250
# 11/11 [==============================] - 3s 245ms/step - loss: 0.7362 - accuracy: 0.8720
# Epoch 135/250
# 11/11 [==============================] - 3s 219ms/step - loss: 0.7517 - accuracy: 0.8644
# Epoch 136/250
# 11/11 [==============================] - 2s 221ms/step - loss: 0.7695 - accuracy: 0.8409
# Epoch 137/250
# 11/11 [==============================] - 2s 204ms/step - loss: 0.7202 - accuracy: 0.8689
# Epoch 138/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6853 - accuracy: 0.8818
# Epoch 139/250
# 11/11 [==============================] - 2s 210ms/step - loss: 0.6641 - accuracy: 0.8803
# Epoch 140/250
# 11/11 [==============================] - 2s 225ms/step - loss: 0.6486 - accuracy: 0.8864
# Epoch 141/250
# 11/11 [==============================] - 3s 269ms/step - loss: 0.6381 - accuracy: 0.8894
# Epoch 142/250
# 11/11 [==============================] - 2s 203ms/step - loss: 0.6366 - accuracy: 0.8955
# Epoch 143/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6051 - accuracy: 0.8955
# Epoch 144/250
# 11/11 [==============================] - 2s 205ms/step - loss: 0.6137 - accuracy: 0.8932
# Epoch 145/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.6056 - accuracy: 0.8917
# Epoch 146/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.5929 - accuracy: 0.8992
# Epoch 147/250
# 11/11 [==============================] - 4s 345ms/step - loss: 0.5874 - accuracy: 0.8947
# Epoch 148/250
# 11/11 [==============================] - 3s 229ms/step - loss: 0.5689 - accuracy: 0.9030
# Epoch 149/250
# 11/11 [==============================] - 2s 221ms/step - loss: 0.5565 - accuracy: 0.9053
# Epoch 150/250
# 11/11 [==============================] - 3s 229ms/step - loss: 0.5504 - accuracy: 0.9053
# Epoch 151/250
# 11/11 [==============================] - 2s 218ms/step - loss: 0.5517 - accuracy: 0.9121
# Epoch 152/250
# 11/11 [==============================] - 2s 215ms/step - loss: 0.5390 - accuracy: 0.9174
# Epoch 153/250
# 11/11 [==============================] - 4s 335ms/step - loss: 0.5306 - accuracy: 0.9045
# Epoch 154/250
# 11/11 [==============================] - 3s 254ms/step - loss: 0.5234 - accuracy: 0.9159
# Epoch 155/250
# 11/11 [==============================] - 2s 212ms/step - loss: 0.5282 - accuracy: 0.9061
# Epoch 156/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.5162 - accuracy: 0.9083
# Epoch 157/250
# 11/11 [==============================] - 3s 229ms/step - loss: 0.5087 - accuracy: 0.9129
# Epoch 158/250
# 11/11 [==============================] - 2s 225ms/step - loss: 0.4990 - accuracy: 0.9121
# Epoch 159/250
# 11/11 [==============================] - 3s 319ms/step - loss: 0.4944 - accuracy: 0.9129
# Epoch 160/250
# 11/11 [==============================] - 3s 260ms/step - loss: 0.4855 - accuracy: 0.9205
# Epoch 161/250
# 11/11 [==============================] - 2s 220ms/step - loss: 0.4804 - accuracy: 0.9205
# Epoch 162/250
# 11/11 [==============================] - 2s 223ms/step - loss: 0.4823 - accuracy: 0.9212
# Epoch 163/250
# 11/11 [==============================] - 3s 228ms/step - loss: 0.4795 - accuracy: 0.9189
# Epoch 164/250
# 11/11 [==============================] - 2s 223ms/step - loss: 0.4728 - accuracy: 0.9189
# Epoch 165/250
# 11/11 [==============================] - 3s 259ms/step - loss: 0.4670 - accuracy: 0.9152
# Epoch 166/250
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4559 - accuracy: 0.9227
# Epoch 167/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.4555 - accuracy: 0.9189
# Epoch 168/250
# 11/11 [==============================] - 3s 227ms/step - loss: 0.4434 - accuracy: 0.9205
# Epoch 169/250
# 11/11 [==============================] - 2s 221ms/step - loss: 0.4373 - accuracy: 0.9318
# Epoch 170/250
# 11/11 [==============================] - 3s 230ms/step - loss: 0.4350 - accuracy: 0.9242
# Epoch 171/250
# 11/11 [==============================] - 2s 213ms/step - loss: 0.4295 - accuracy: 0.9311
# Epoch 172/250
# 11/11 [==============================] - 4s 403ms/step - loss: 0.4262 - accuracy: 0.9265
# Epoch 173/250
# 11/11 [==============================] - 2s 205ms/step - loss: 0.4179 - accuracy: 0.9288
# Epoch 174/250
# 11/11 [==============================] - 2s 203ms/step - loss: 0.4206 - accuracy: 0.9333
# Epoch 175/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4121 - accuracy: 0.9273
# Epoch 176/250
# 11/11 [==============================] - 2s 211ms/step - loss: 0.4152 - accuracy: 0.9273
# Epoch 177/250
# 11/11 [==============================] - 3s 249ms/step - loss: 0.4088 - accuracy: 0.9333
# Epoch 178/250
# 11/11 [==============================] - 3s 212ms/step - loss: 0.4126 - accuracy: 0.9295
# Epoch 179/250
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4100 - accuracy: 0.9295
# Epoch 180/250
# 11/11 [==============================] - 2s 206ms/step - loss: 0.4039 - accuracy: 0.9288
# Epoch 181/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.4062 - accuracy: 0.9280
# Epoch 182/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3989 - accuracy: 0.9333
# Epoch 183/250
# 11/11 [==============================] - 3s 273ms/step - loss: 0.3900 - accuracy: 0.9356
# Epoch 184/250
# 11/11 [==============================] - 5s 411ms/step - loss: 0.3865 - accuracy: 0.9341
# Epoch 185/250
# 11/11 [==============================] - 5s 415ms/step - loss: 0.3814 - accuracy: 0.9402
# Epoch 186/250
# 11/11 [==============================] - 3s 226ms/step - loss: 0.3750 - accuracy: 0.9386
# Epoch 187/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3832 - accuracy: 0.9402
# Epoch 188/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3910 - accuracy: 0.9348
# Epoch 189/250
# 11/11 [==============================] - 2s 224ms/step - loss: 0.4022 - accuracy: 0.9326
# Epoch 190/250
# 11/11 [==============================] - 4s 324ms/step - loss: 0.4345 - accuracy: 0.9167
# Epoch 191/250
# 11/11 [==============================] - 3s 247ms/step - loss: 0.4460 - accuracy: 0.9159
# Epoch 192/250
# 11/11 [==============================] - 2s 226ms/step - loss: 0.4693 - accuracy: 0.9076
# Epoch 193/250
# 11/11 [==============================] - 3s 275ms/step - loss: 0.6034 - accuracy: 0.8598
# Epoch 194/250
# 11/11 [==============================] - 3s 287ms/step - loss: 0.7658 - accuracy: 0.8068
# Epoch 195/250
# 11/11 [==============================] - 3s 275ms/step - loss: 0.8817 - accuracy: 0.7826
# Epoch 196/250
# 11/11 [==============================] - 3s 236ms/step - loss: 0.8606 - accuracy: 0.7742
# Epoch 197/250
# 11/11 [==============================] - 3s 261ms/step - loss: 0.7941 - accuracy: 0.8076
# Epoch 198/250
# 11/11 [==============================] - 3s 236ms/step - loss: 0.7240 - accuracy: 0.8258
# Epoch 199/250
# 11/11 [==============================] - 3s 237ms/step - loss: 0.5852 - accuracy: 0.8659
# Epoch 200/250
# 11/11 [==============================] - 3s 239ms/step - loss: 0.5069 - accuracy: 0.9106
# Epoch 201/250
# 11/11 [==============================] - 2s 199ms/step - loss: 0.4618 - accuracy: 0.9205
# Epoch 202/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.4171 - accuracy: 0.9235
# Epoch 203/250
# 11/11 [==============================] - 2s 211ms/step - loss: 0.3860 - accuracy: 0.9379
# Epoch 204/250
# 11/11 [==============================] - 2s 202ms/step - loss: 0.3626 - accuracy: 0.9394
# Epoch 205/250
# 11/11 [==============================] - 3s 263ms/step - loss: 0.3508 - accuracy: 0.9417
# Epoch 206/250
# 11/11 [==============================] - 3s 261ms/step - loss: 0.3436 - accuracy: 0.9439
# Epoch 207/250
# 11/11 [==============================] - 2s 205ms/step - loss: 0.3383 - accuracy: 0.9424
# Epoch 208/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3342 - accuracy: 0.9455
# Epoch 209/250
# 11/11 [==============================] - 2s 213ms/step - loss: 0.3372 - accuracy: 0.9439
# Epoch 210/250
# 11/11 [==============================] - 2s 204ms/step - loss: 0.3301 - accuracy: 0.9439
# Epoch 211/250
# 11/11 [==============================] - 3s 227ms/step - loss: 0.3277 - accuracy: 0.9439
# Epoch 212/250
# 11/11 [==============================] - 4s 350ms/step - loss: 0.3310 - accuracy: 0.9455
# Epoch 213/250
# 11/11 [==============================] - 3s 215ms/step - loss: 0.3270 - accuracy: 0.9455
# Epoch 214/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3206 - accuracy: 0.9477
# Epoch 215/250
# 11/11 [==============================] - 2s 220ms/step - loss: 0.3155 - accuracy: 0.9508
# Epoch 216/250
# 11/11 [==============================] - 2s 198ms/step - loss: 0.3188 - accuracy: 0.9470
# Epoch 217/250
# 11/11 [==============================] - 2s 210ms/step - loss: 0.3155 - accuracy: 0.9455
# Epoch 218/250
# 11/11 [==============================] - 3s 281ms/step - loss: 0.3131 - accuracy: 0.9492
# Epoch 219/250
# 11/11 [==============================] - 3s 267ms/step - loss: 0.3139 - accuracy: 0.9485
# Epoch 220/250
# 11/11 [==============================] - 2s 205ms/step - loss: 0.3151 - accuracy: 0.9485
# Epoch 221/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3089 - accuracy: 0.9500
# Epoch 222/250
# 11/11 [==============================] - 2s 208ms/step - loss: 0.3128 - accuracy: 0.9485
# Epoch 223/250
# 11/11 [==============================] - 2s 195ms/step - loss: 0.3083 - accuracy: 0.9477
# Epoch 224/250
# 11/11 [==============================] - 2s 201ms/step - loss: 0.3139 - accuracy: 0.9492
# Epoch 225/250
# 11/11 [==============================] - 2s 204ms/step - loss: 0.3039 - accuracy: 0.9515
# Epoch 226/250
# 11/11 [==============================] - 3s 241ms/step - loss: 0.3057 - accuracy: 0.9523
# Epoch 227/250
# 11/11 [==============================] - 2s 223ms/step - loss: 0.3039 - accuracy: 0.9470
# Epoch 228/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.3024 - accuracy: 0.9508
# Epoch 229/250
# 11/11 [==============================] - 2s 201ms/step - loss: 0.3005 - accuracy: 0.9515
# Epoch 230/250
# 11/11 [==============================] - 2s 209ms/step - loss: 0.3016 - accuracy: 0.9492
# Epoch 231/250
# 11/11 [==============================] - 4s 337ms/step - loss: 0.2941 - accuracy: 0.9538
# Epoch 232/250
# 11/11 [==============================] - 3s 235ms/step - loss: 0.2961 - accuracy: 0.9530
# Epoch 233/250
# 11/11 [==============================] - 2s 206ms/step - loss: 0.2984 - accuracy: 0.9485
# Epoch 234/250
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2987 - accuracy: 0.9508
# Epoch 235/250
# 11/11 [==============================] - 2s 205ms/step - loss: 0.2975 - accuracy: 0.9477
# Epoch 236/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.3002 - accuracy: 0.9455
# Epoch 237/250
# 11/11 [==============================] - 3s 289ms/step - loss: 0.2969 - accuracy: 0.9470
# Epoch 238/250
# 11/11 [==============================] - 3s 266ms/step - loss: 0.2928 - accuracy: 0.9508
# Epoch 239/250
# 11/11 [==============================] - 2s 210ms/step - loss: 0.2989 - accuracy: 0.9515
# Epoch 240/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.3024 - accuracy: 0.9500
# Epoch 241/250
# 11/11 [==============================] - 2s 213ms/step - loss: 0.2939 - accuracy: 0.9523
# Epoch 242/250
# 11/11 [==============================] - 2s 201ms/step - loss: 0.3288 - accuracy: 0.9409
# Epoch 243/250
# 11/11 [==============================] - 3s 252ms/step - loss: 0.3252 - accuracy: 0.9409
# Epoch 244/250
# 11/11 [==============================] - 4s 315ms/step - loss: 0.3171 - accuracy: 0.9477
# Epoch 245/250
# 11/11 [==============================] - 3s 244ms/step - loss: 0.2990 - accuracy: 0.9523
# Epoch 246/250
# 11/11 [==============================] - 2s 217ms/step - loss: 0.2953 - accuracy: 0.9508
# Epoch 247/250
# 11/11 [==============================] - 2s 206ms/step - loss: 0.2906 - accuracy: 0.9538
# Epoch 248/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2926 - accuracy: 0.9538
# Epoch 249/250
# 11/11 [==============================] - 2s 207ms/step - loss: 0.2846 - accuracy: 0.9523
# Epoch 250/250
# 11/11 [==============================] - 3s 295ms/step - loss: 0.2780 - accuracy: 0.9538

# %%
import numpy as np
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
	result = list()
	in_text = seed_text
	for _ in range(n_words):
		encoded = tokenizer.texts_to_sequences([in_text])[0]
		encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre', padding='post')
		y_pred = model.predict(encoded, verbose=0)
		predicted_index = np.argmax(y_pred)
		out_word = ''
		for word, index in tokenizer.word_index.items():
			if index == predicted_index:
				out_word = word
				break
		in_text += ' ' + out_word
		result.append(out_word)
	return ' '.join(result)

in_filename = 'samplerv1.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')
seq_length = len(lines[0].split()) - 1

model = load_model('model.h5')

tokenizer = load(open('tokenizer.pkl', 'rb'))

seed_text = lines[randint(0,len(lines))]
print(seed_text + '\n')

generated = generate_seq(model, tokenizer, 44, seed_text, 1000)
print(generated)
# Out:
#  Kenny glances to the door. He considers for a long moment. KENNY The friend. Kenny breaks the gaze. He begins to whistle again. The CAMERA drifts away, finding the far DOOR to the inner office, Kenny
#
# fatma
